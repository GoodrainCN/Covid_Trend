# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn import datasets
import pandas as pd
import numpy as np
####
data = pd.read_csv('dataset/OR2020.csv', usecols=[15]) #x
fish = pd.read_csv('dataset/OR2020.csv', usecols=[2]) #y
data = np.array(data) #x
fish = np.array(fish) #y
####
import matplotlib.pyplot as plt
plt.plot(data, fish)
plt.show()
####
X_train, X_test, Y_train, Y_test = train_test_split(data, fish, train_size=.8)
plt.scatter(X_train,Y_train, color='b')
plt.scatter(X_test,Y_test, color='r')
plt.show()
####
model = LinearRegression()
model.fit(X_train, Y_train)
####
a = model.intercept_
b = model.coef_
print(a[0])
print(b[0][0])
####
model.score(X_test,Y_test)
output_y = model.predict(X_test)
plt.scatter(X_test,output_y, color='b')
plt.scatter(X_test,Y_test, color='r')
x = []
y = []
y1 = []
for i in range(len(data)):
    x.append(i)
    y.append((i*b[0][0])+a[0])
    y1.append(0)
#print(y)
#x = x.array(x)
#y = y.array(y)
plt.plot(x,y)
#plt.plot(x,y1)
# Out:
# -71648.80283865983
# 574.0431349411319

# %%
labels = ['2020/5', '2020/8', '2020/12', '2021/2', '20211/6', '2021/9', '2021/12']

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn import datasets
import pandas as pd
import numpy as np
####
data = pd.read_csv('dataset/OR2020.csv', usecols=[15]) #x
new_inc = pd.read_csv('dataset/OR2020.csv', usecols=[5]) #y
data = np.array(data) #x
new_inc = np.array(new_inc) #y
####


import matplotlib.pyplot as plt
plt.plot(data, new_inc, 'r')
plt.xticks(
    [0,100,200,300,400,500,600,700],
    ['2020/1','2020/5', '2020/8', '2020/12', '2021/2', '20211/6', '2021/9', '2021/12']
)
plt.show()
####
X_train, X_test, Y_train, Y_test = train_test_split(data, new_inc, train_size=.8)
plt.scatter(X_train,Y_train, color='b')
plt.scatter(X_test,Y_test, color='r')
plt.xticks(
    [0,100,200,300,400,500,600,700],
    ['2020/1','2020/5', '2020/8', '2020/12', '2021/2', '20211/6', '2021/9', '2021/12']
)
plt.show()
####
model = LinearRegression()
model.fit(X_train, Y_train)
####
a = model.intercept_
b = model.coef_
print(a[0])
print(b[0][0])
####
model.score(X_test,Y_test)
output_y = model.predict(X_test)
plt.xticks(
    [0,100,200,300,400,500,600,700],
    ['2020/1','2020/5', '2020/8', '2020/12', '2021/2', '20211/6', '2021/9', '2021/12']
)
plt.scatter(X_test,output_y, color='b')
plt.scatter(X_test,Y_test, color='r')
x = []
y = []
y1 = []
for i in range(len(data)):
    x.append(i)
    y.append((i*b[0][0])+a[0])
    y1.append(0)
#print(y)
#x = x.array(x)
#y = y.array(y)
plt.plot(x,y)
#plt.plot(x,y1)
# Out:
# -39.44667513091656
# 1.830108817703909

# %%
def nigger():
    from sklearn.linear_model import LinearRegression
    from sklearn.model_selection import train_test_split
    from sklearn import datasets
    import pandas as pd
    import numpy as np
