# %%
import sklearn

# %%
import csv

confirmed = []
with open('day_wise.csv') as csv_file:
    csv_reader = csv.reader(csv_file, delimiter=',')
    headers = next(csv_reader)
    #print(headers)
    line_count = 0
    for i in csv_reader:
        confirmed.append(i[1])

print(confirmed)
# Out:
# ['555', '654', '941', '1434', '2118', '2927', '5578', '6166', '8234', '9927', '12038', '16787', '19887', '23898', '27643', '30802', '34334', '37068', '40095', '42633', '44675', '46561', '60206', '66690', '68765', '70879', '72815', '74609', '75030', '75577', '76206', '77967', '78290', '78854', '79707', '80670', '82034', '83411', '85306', '87690', '89664', '92241', '94540', '97331', '101274', '105312', '109266', '113166', '118190', '125853', '131603', '146008', '157114', '168260', '182919', '198757', '218343', '246261', '275869', '308175', '341585', '383750', '424889', '475706', '538666', '603066', '670723', '730300', '794939', '871355', '947569', '1028968', '1112123', '1192586', '1264304', '1336976', '1413849', '1497624', '1584249', '1671907', '1748872', '1845653', '1915247', '1985174', '2066003', '2162715', '2250439', '2324396', '2404919', '2478258', '2553508', '2630314', '2719327', '2806267', '2891199', '2964146', '3032850', '3108149', '3185195', '3268876', '3355922', '3437608', '35
# ...

# %%
import pandas as pd
import matplotlib as plt
df = pd.read_csv('day_wise.csv', sep=',')
#df = pd.read_csv('day_wise.csv', index_col='Date')
df
# Out:
#           Date  Confirmed  Deaths  Recovered   Active  New cases  New deaths  \
# 0    2020/1/22        555      17         28      510          0           0
# 1    2020/1/23        654      18         30      606         99           1
# 2    2020/1/24        941      26         36      879        287           8
# 3    2020/1/25       1434      42         39     1353        493          16
# 4    2020/1/26       2118      56         52     2010        684          14
# ..         ...        ...     ...        ...      ...        ...         ...
# 183  2020/7/23   15510481  633506    8710969  6166006     282756        9966
# 184  2020/7/24   15791645  639650    8939705  6212290     281164        6144
# 185  2020/7/25   16047190  644517    9158743  6243930     255545        4867
# 186  2020/7/26   16251796  648621    9293464  6309711     204606        4104
# 187  2020/7/27   16480485  654036    9468087  6358362     228693        5415
#
# ...

# %%
data = df.Confirmed
print(data)
# Out:
# 0           555
# 1           654
# 2           941
# 3          1434
# 4          2118
#          ...
# 183    15510481
# 184    15791645
# 185    16047190
# 186    16251796
# 187    16480485
# Name: Confirmed, Length: 188, dtype: int64

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn import datasets
import pandas as pd
import numpy as np

target = pd.read_csv('day_wise.csv', usecols=[1])
#date = pd.read_csv('day_wise.csv', usecols=[0])
data = []
temp = 1
for i in range(len(target)):
    data.append(temp)
    temp += 1
data = np.array(data)
target = np.array(target)
import matplotlib.pyplot as plt
plt.scatter(data, target)
plt.show()

X_train, X_test, Y_train, Y_test = train_test_split(data,target,train_size=.8)

plt.scatter(X_train,Y_train, color='b')
plt.scatter(X_test,Y_test, color='r')

plt.show()

model = LinearRegression()
model.fit(X_train, Y_train)

a = model.intercept_
b = model.coef_

print(a)
print(b)

model.score(X_test,Y_test)

output_y = model.predict(X_test)

plt.scatter(X_test,output_y, color='b')
plt.scatter(X_test,Y_test, color='r')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_2696/2294686952.py in <module>
#      26
#      27 model = LinearRegression()
# ---> 28 model.fit(X_train, Y_train)
#      29
#      30 a = model.intercept_
#
# ~\anaconda3\envs\pyc\lib\site-packages\sklearn\linear_model\_base.py in fit(self, X, y, sample_weight)
#     660         accept_sparse = False if self.positive else ["csr", "csc", "coo"]
#     661
# --> 662         X, y = self._validate_data(
#     663             X, y, accept_sparse=accept_sparse, y_numeric=True, multi_output=True
#     664         )
#
# ~\anaconda3\envs\pyc\lib\site-packages\sklearn\base.py in _validate_data(self, X, y, reset, validate_separately, **check_params)
#     574                 y = check_array(y, **check_y_params)
#     575             else:
# --> 576                 X, y = check_X_y(X, y, **check_params)
# ...

# %%
X_train, X_test, Y_train, Y_test = train_test_split(data,target,train_size=.8)

plt.scatter(X_train,Y_train, color='b')
plt.scatter(X_test,Y_test, color='r')

plt.show()

# %%
model = LinearRegression()
model.fit(X_train, Y_train)
# Out:
# LinearRegression()

# %%
a = model.intercept_
b = model.coef_

print(a)
print(b)
# Out:
# 38.45880720257846
# [0.00024276]

# %%
model.score(X_test,Y_test)

output_y = model.predict(X_test)

plt.scatter(X_test,output_y, color='b')
plt.scatter(X_test,Y_test, color='r')

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn import datasets
import pandas as pd
import numpy as np

data = pd.read_csv('day_wise.csv', usecols=[2])
#date = pd.read_csv('day_wise.csv', usecols=[0])
date = []
temp = 1
for i in range(len(data)):
    date.append(temp)
    temp += 1
data = np.array(data)
date = np.array(date)
#print(date)
import matplotlib.pyplot as plt
plt.scatter(data, date)
plt.show()
####

X_train, X_test, Y_train, Y_test = train_test_split(data,date,train_size=.8)

plt.scatter(X_train,Y_train, color='b')
plt.scatter(X_test,Y_test, color='r')

plt.show()
####
model = LinearRegression()
model.fit(X_train, Y_train)
####
a = model.intercept_
b = model.coef_

print(a)
print(b)
####
model.score(X_test,Y_test)

output_y = model.predict(X_test)

plt.scatter(X_test,output_y, color='b')
plt.scatter(X_test,Y_test, color='r')
# Out:
# 38.45880720257846
# [0.00024276]

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn import datasets
import pandas as pd
import numpy as np
####
data = pd.read_csv('day_wise.csv', usecols=[12]) #x
date = pd.read_csv('day_wise.csv', usecols=[2]) #y
data = np.array(data) #x
date = np.array(date) #y
####
import matplotlib.pyplot as plt
plt.scatter(data, date)
plt.show()
####
X_train, X_test, Y_train, Y_test = train_test_split(data, date, train_size=.8)
plt.scatter(X_train,Y_train, color='b')
plt.scatter(X_test,Y_test, color='r')

plt.show()
####
model = LinearRegression()
model.fit(X_train, Y_train)
####
a = model.intercept_
b = model.coef_

print(a[0])
print(b[0][0])
####
model.score(X_test,Y_test)

output_y = model.predict(X_test)

plt.scatter(X_test,output_y, color='b')
plt.scatter(X_test,Y_test, color='r')

x = []
y = []
y1 = []
for i in range(len(data)):
    x.append(i)
    y.append((i*b[0][0])+a[0])
    y1.append(0)
#print(y)
#x = x.array(x)
#y = y.array(y)
plt.plot(x,y)
plt.plot(x,y1)
# Out:
# -129489.36710978375
# 3816.243964265097

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn import datasets
import pandas as pd
import numpy as np
########
data = pd.read_csv('day_wise.csv', usecols=[12])
date = pd.read_csv('day_wise.csv', usecols=[2])
data = np.array(data)
date = np.array(date)
###########
import matplotlib.pyplot as plt
plt.scatter(data, date)
plt.show()

X_train, X_test, Y_train, Y_test = train_test_split(data, date, train_size=.8)

plt.scatter(X_train,Y_train, color='b')
plt.scatter(X_test,Y_test, color='r')

plt.show()

model = LinearRegression()
model.fit(X_train, Y_train)

a = model.intercept_
b = model.coef_

print(a)
print(b)

model.score(X_test,Y_test)

output_y = model.predict(X_test)

plt.scatter(X_test,output_y, color='b')
plt.scatter(X_test,Y_test, color='r')
# Out:
# [-128672.68195698]
# [[3835.2568578]]

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn import datasets
import pandas as pd
import numpy as np
####
data = pd.read_excel('fish.xlsx', usecols=[0]) #x
fish = pd.read_excel('fish.xlsx', usecols=[2]) #y
data = np.array(data) #x
fish = np.array(fish) #y
####
import matplotlib.pyplot as plt
plt.scatter(data, fish)
plt.show()
####
X_train, X_test, Y_train, Y_test = train_test_split(data, fish, train_size=.8)
plt.scatter(X_train,Y_train, color='b')
plt.scatter(X_test,Y_test, color='r')

plt.show()
####
model = LinearRegression()
model.fit(X_train, Y_train)
####
a = model.intercept_
b = model.coef_

print(a[0])
print(b[0][0])
####
model.score(X_test,Y_test)

output_y = model.predict(X_test)

plt.scatter(X_test,output_y, color='b')
plt.scatter(X_test,Y_test, color='r')

x = []
y = []
y1 = []
for i in range(len(data)):
    x.append(i)
    y.append((i*b[0][0])+a[0])
    y1.append(0)
#print(y)
#x = x.array(x)
#y = y.array(y)
plt.plot(x,y)
#plt.plot(x,y1)
# Out:
# 77841.72964382131
# -2295.7419228424633

# %%
import torch
from torch import nn
import numpy as np
import matplotlib.pyplot as plt
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
import torch
x = torch.rand(5, 3)
print(x)
# Out:
# tensor([[0.0350, 0.1896, 0.2388],
#         [0.6314, 0.2452, 0.2566],
#         [0.8059, 0.4619, 0.0094],
#         [0.3479, 0.2623, 0.1997],
#         [0.5209, 0.7834, 0.1923]])

# %%
import torch
torch.cuda.is_available()
# Out:
# True

# %%
import pandas as pd
import numpy as np

data = pd.read_excel('demo.xlsx', usecols=[2])
target = pd.read_excel('demo.xlsx', usecols=[3])

data = np.array(data)
target = np.array(target)

from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn import datasets 

import matplotlib.pyplot as plt
plt.scatter(data,target)
plt.show()

X_train, X_test, Y_train, Y_test = train_test_split(data,target,train_size=.8)

plt.scatter(X_train,Y_train, color='b')
plt.scatter(X_test,Y_test, color='r')

plt.show()

model = LinearRegression()
model.fit(X_train, Y_train)

a = model.intercept_
b = model.coef_

print(a)
print(b)

model.score(X_test,Y_test)

output_y = model.predict(X_test)

plt.scatter(X_test,output_y, color='b')
plt.scatter(X_test,Y_test, color='r')
# Out:
# [-61900.68103213]
# [[1149.8395284]]

# %%
import torch

with open("demo02.csv", "r", encoding="utf-8") as f:
    data = f.read()

data = [row.split(',') for row in  data.split("\n")]

# value = [int(each[1]) for each in data]
value = [float(each[1]) for each in data]

train  = value[:-300]
test = value[-300:]

li_x = []
li_y = []
seq = 2


# 因为数据集较少，序列长度太长会影响结果
for i in range(len(data[:-300]) - seq):
    # 输入就是[x,x+1]天的数据，输出时x+2天的数据
    li_x.append(train[i: i+seq])
    li_y.append(train[i+seq])

t_x = []
t_y = []
# 因为数据集较少，序列长度太长会影响结果
for i in range(len(data[-300:]) - seq):
    # 输入就是[x,x+1]天的数据，输出时x+2天的数据*
    t_x.append(test[i: i+seq])
    t_y.append(test[i+seq])



# # 分训练和测试集
# train_x = (torch.tensor(li_x[:-30]).float() / 1000.).reshape(-1, seq, 1).to(device)
# train_y = (torch.tensor(li_y[:-30]).float() / 1000.).reshape(-1, 1).to(device)

# print(train_x.shape)

# test_x = (torch.tensor(t_x[-30:]).float() / 1000.).reshape(-1, seq, 1).to(device)
# test_y = (torch.tensor(t_y[-30:]).float() / 1000.).reshape(-1, 1).to(device)


# 分训练和测试集
train_x = (torch.tensor(li_x).float() / 1000.).reshape(-1, seq, 1).to(device)
train_y = (torch.tensor(li_y).float() / 1000.).reshape(-1, 1).to(device)

print(train_x.shape)

test_x = (torch.tensor(t_x).float() / 1000.).reshape(-1, seq, 1).to(device)
test_y = (torch.tensor(t_y).float() / 1000.).reshape(-1, 1).to(device)
# Out:
# torch.Size([1172, 2, 1])

# %%
import pandas as pd
import numpy as np

data = pd.read_csv('day_wise.csv', usecols=[12])
target = pd.read_csv('day_wise.csv', usecols=[2])

data = np.array(data)
target = np.array(target)

from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn import datasets 

import matplotlib.pyplot as plt
plt.scatter(data,target)
plt.show()

X_train, X_test, Y_train, Y_test = train_test_split(data,target,train_size=.8)

plt.scatter(X_train,Y_train, color='b')
plt.scatter(X_test,Y_test, color='r')

plt.show()

model = LinearRegression()
model.fit(X_train, Y_train)

a = model.intercept_
b = model.coef_

print(a)
print(b)

model.score(X_test,Y_test)

output_y = model.predict(X_test)

plt.scatter(X_test,output_y, color='b')
plt.scatter(X_test,Y_test, color='r')
# Out:
# [-145573.57867456]
# [[3971.19715096]]

# %%
class Net(nn.Module):
    def __init__(self):
        super(Net, self).__init__()
        self.lstm = nn.LSTM(input_size=1, hidden_size=32, num_layers=1, batch_first=True)
        # 输入格式是1，输出隐藏层大小是32
        # 对于小数据集num_layers不要设置大，否则会因为模型变复杂而导致效果会变差
        # num_layers顾名思义就是有几个lstm层，假如设置成2，就相当于连续经过两个lstm层
        # 原来的输入格式是：(seq, batch, shape)
        # 设置batch_first=True以后，输入格式就可以改为：(batch, seq, shape)，更符合平常使用的习惯
        self.linear = nn.Linear(32*seq, 1)

    def forward(self, x):
        x, (h, c) = self.lstm(x)
        x = x.reshape(-1, 32*seq)
        x = self.linear(x)
        return x

# %%
model = Net().to(device)
optimizer = torch.optim.Adam(model.parameters(), lr=0.003)
loss_fun = nn.MSELoss()

# %%
model.train()
for epoch in range(2000):
    output = model(train_x)
    loss = loss_fun(output, train_y)
    optimizer.zero_grad()
    loss.backward()
    optimizer.step()
    if epoch % 20 == 0 and epoch > 0:
        test_loss = loss_fun(model(test_x), test_y)
        print("epoch:{}, loss:{}, test_loss: {}".format(epoch, loss, test_loss))
# Out:
# epoch:20, loss:0.6881065368652344, test_loss: 1.2490599155426025
# epoch:40, loss:0.08765731751918793, test_loss: 0.0054351757280528545
# epoch:60, loss:0.0189224760979414, test_loss: 0.1270323097705841
# epoch:80, loss:0.009824637323617935, test_loss: 0.041121646761894226
# epoch:100, loss:0.008175784721970558, test_loss: 0.06101714447140694
# epoch:120, loss:0.0075409566052258015, test_loss: 0.051085442304611206
# epoch:140, loss:0.007018274627625942, test_loss: 0.04760584235191345
# epoch:160, loss:0.006479214411228895, test_loss: 0.04445480927824974
# epoch:180, loss:0.005925746168941259, test_loss: 0.040180400013923645
# epoch:200, loss:0.005363017320632935, test_loss: 0.036033112555742264
# epoch:220, loss:0.004797338508069515, test_loss: 0.03204265236854553
# epoch:240, loss:0.004235162865370512, test_loss: 0.02811339497566223
# epoch:260, loss:0.0036819239612668753, test_loss: 0.024090547114610672
# epoch:280, loss:0.0031462081242352724, test_loss: 0.020353242754936218

# %%
model.eval()
# result = li_x[0][:seq-1] + list((model(train_x).data.reshape(-1))*1000) + list((model(test_x).data.reshape(-1))*1000)
result = [0] + list((model(train_x).data.reshape(-1))*00) + list((model(test_x).data.reshape(-1))*1000)

# 绿色曲线只有波动的地方是模型预测的，前面的直线是我手动设置成0了。

# 通过模型计算预测结果并解码后保存到列表里，因为预测是从第seq个开始的，所有前面要加seq-1条数据
plt.plot(value, label="real")
# 原来的走势

plt.plot(train, label="train")

plt.plot(result, label="pred")
# 模型预测的走势
plt.legend(loc='best')

# %%
import torch
print(torch.cuda.get_arch_list())
# Out:
# ['sm_37', 'sm_50', 'sm_60', 'sm_61', 'sm_70', 'sm_75', 'sm_80', 'sm_86', 'compute_37']
